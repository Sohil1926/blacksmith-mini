# %%
from dotenv import load_dotenv
import os
load_dotenv()

import sys
sys.path.append('/home/sohilathare/firecracker-demo/new_backend/workflow')

from basis import get_workflow_runs, get_jobs_from_workflow_run, create_vm  # Removed get_jobs import
github_token = os.getenv('GITHUB_TOKEN')
workflow_runs = get_workflow_runs(github_token)

# %%
print(github_token)

# %%
import json
print(json.dumps(workflow_runs, indent=2))

# %%
jobs1 = get_jobs_from_workflow_run(workflow_runs[0], github_token)
print(json.dumps(jobs1, indent=2))
